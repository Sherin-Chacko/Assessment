# %%
from sqlalchemy import create_engine
import pandas as pd

# File to Load
database_path = "Census_Data.sqlite"
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# Read School and Student Data File and store into Pandas DataFrames
census_df = pd.read_sql(select * FROM Census_Data, conn)

# Present dataframe
census_df.head()
# Out:
#   File "/var/folders/pp/qc9hzpfs53sdnnq5nfxmk00c0000gn/T/ipykernel_4875/2684078112.py", line 10
#     census_df = pd.read_sql(select * FROM Census_Data, conn)
#                                           ^
# SyntaxError: invalid syntax

# %%
unique_df = pd.Series(l_station_df['MAP_ID'].unique())
unique_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pp/qc9hzpfs53sdnnq5nfxmk00c0000gn/T/ipykernel_4875/1073392283.py in <module>
# ----> 1 unique_df = pd.Series(l_station_df['MAP_ID'].unique())
#       2 unique_df
#
# NameError: name 'l_station_df' is not defined

# %%
df = pd.merge(ridership_df, l_station_df, how='left', left_on='station_id', right_on ='MAP_ID')
df
# Out:
#         station_id          STATION_NAME_x        date daytype  rides  \
# 0            40050                   Davis    1/1/2016       U   1415
# 1            40050                   Davis    1/1/2016       U   1415
# 2            41200                  Argyle    1/1/2016       U   1741
# 3            41200                  Argyle    1/1/2016       U   1741
# 4            40970      Cicero-Forest Park    1/1/2016       U    722
# ...            ...                     ...         ...     ...    ...
# 539498       41680           Oakton-Skokie  11/30/2020       W    191
# 539499       41690  Cermak-McCormick Place  11/30/2020       W    373
# 539500       41690  Cermak-McCormick Place  11/30/2020       W    373
# 539501       41700       Washington/Wabash  11/30/2020       W   2041
# 539502       41700       Washington/Wabash  11/30/2020       W   2041
#
#         STOP_ID DIRECTION_ID                              STOP_NAME  \
# ...

# %%
df[df['Location'] < '(41.881)']['rides'].drop_duplicates
# Out:
# <bound method Series.drop_duplicates of 4          722
# 5          722
# 8          764
# 9          764
# 17         586
#           ...
# 539478    1168
# 539487     486
# 539488     486
# 539499     373
# 539500     373
# Name: rides, Length: 222704, dtype: int64>

# %%
df[df['DIRECTION_ID'] == 'S']['rides'].sum()
# Out:
# 745485374
